# %%
import pandas as pd
import numpy as np
data = [1.1,1.4,1.5,1.8,1.9,2,2.1,2.4,2.5,2.8,3,3,4.1,7]
df = pd.DataFrame(data)
# Out:
# 0    2.614286
# dtype: float64

# %%
print(df.count())
print(df.sum())

# %%
print(df.mean())
# Out:
# 0    36.6
# dtype: float64

# %%
print(df.var())
# Out:
# 0    2.204396
# dtype: float64

# %%
print(df.std())
# Out:
# 0    1.484721
# dtype: float64
